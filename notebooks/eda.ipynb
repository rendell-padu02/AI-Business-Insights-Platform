# %%
import sys, os

# Get the parent directory of the notebook (the project root)
PROJECT_ROOT = os.path.abspath("..")

# Add it to Python path if not there already
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root added to sys.path:", PROJECT_ROOT)
# Out:
# Project root added to sys.path: c:\Users\rende\OneDrive\Desktop\Data Analysis Projects\AI-Business-Insights-Platform\AI-Business-Insights-Platform

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from ydata_profiling import ProfileReport
from src.data_cleaning import load_data

# Load datasets
superstore = load_data("../data/raw/Superstore.csv")
churn = load_data("../data/raw/Telco_customer_churn.csv")

print("Superstore Shape:", superstore.shape)
print(superstore.head())

print("Churn Shape:", churn.shape)
print(churn.head())

# Basic info
superstore.info()
churn.info()

# Missing values
print(superstore.isna().sum())
print(churn.isna().sum())

# Quick visuals
sns.pairplot(superstore.select_dtypes(include=['float64', 'int64']))
plt.show()

# Profiling report (auto insights)
profile1 = ProfileReport(superstore, title="Superstore Profiling Report")
profile1.to_file("superstore_report.html")

profile2 = ProfileReport(churn, title="Churn Profiling Report")
profile2.to_file("churn_report.html")
# Out:
# Superstore Shape: (9994, 21)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
# ...
